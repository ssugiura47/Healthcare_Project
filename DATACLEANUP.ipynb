# %%
import pandas as pd
import csv
import json
import requests

# %%
medically_underserved = pd.read_csv("medically_underserved.csv")
medically_underserved
# Out:
#      OBJECTID  OBJECTID_1    MuaSrcID MuaDgnTpCD                  MuaDgnTypD  \
# 0           1         198         231        MUA  Medically Underserved Area
# 1           2         199         232        MUA  Medically Underserved Area
# 2           3         200         233        MUA  Medically Underserved Area
# 3           4         201         234        MUA  Medically Underserved Area
# 4           5         202         235        MUA  Medically Underserved Area
# ..        ...         ...         ...        ...                         ...
# 167       168        4003  1063722335        MUA  Medically Underserved Area
# 168       169        4004  1064007760        MUA  Medically Underserved Area
# 169       170        4005  1064107865        MUA  Medically Underserved Area
# 170       171        4006  1064475596        MUA  Medically Underserved Area
# 171       172        4007  1064928092        MUA  Medically Underserved Area
#
# ...
